# %%
# %matplotlib inline
from numpy import *
from matplotlib.pyplot import *

# %% [markdown]
# Todo:
#
# Run ME for foward scattering and get G(tau)
# Run DQMC and produce G(tau) for same parameters
# Figure out analytic solution for t=0.  Compare with G(tau) from above
# Figure out analytic solution for t!=0? Compare with G(tau) from above

# %%
[Nk,Nw,beta,g,omega,q0,superconductivity] = load("../data/params.txt.npy")
Nk = int(Nk)
Nw = int(Nw)

iw_fermi = zeros(Nw, dtype=complex)
Nw2 = int(Nw/2.)
for n in range(Nw):
        iw_fermi[n] = 1j*(2.*(n - Nw2) + 1.)*pi/beta
ws = imag(iw_fermi)

# %%
eq = load("../data/Geqfft.npy")/beta
print shape(eq)
# Out:
# (31L, 31L, 2L, 2L)

# %%
figure()
imshow(real(eq[:,:,0,0]))
colorbar()
title("G")

figure()
imshow(imag(eq[:,:,0,0]))
colorbar()
title("G")

print sum(eq[:,:,0,0])
# Out:
# (-0.000230350207779+1.81521464526e-15j)

# %%
figure()
imshow(real(eq[:,:,0,1]),vmin=-0.23,vmax=0)
colorbar()
title("F")

figure()
imshow(imag(eq[:,:,0,1]))
colorbar()
title("F")


print sum(eq[:,:,0,0])
# Out:
# (-0.000230350207779+1.81521464526e-15j)

# %%
mat = zeros([Nk,Nk])

def Ek(kx,ky):
    return -2*0.25*(cos(kx)+cos(ky))

for i in range(Nk):
    for j in range(Nk):
        kx = -pi + 2*pi/Nk*i + pi/Nk
        ky = -pi + 2*pi/Nk*j + pi/Nk
        if(abs(Ek(kx,ky))<=0.2):
            mat[i,j] = 1.0
            
figure()
imshow(mat)

# %%
G = load("../data/G.npy")

# %%
figure()
plot(ws,real(G[0,0,:]),'r')
plot(ws,imag(G[0,0,:]),'b')

figure()
for ik1 in range(Nk):
    for ik2 in range(Nk):
        plot(ws,real(G[ik1,ik2,:]),'r')
        plot(ws,imag(G[ik1,ik2,:]),'b')

# %%
G = load("../data/F.npy")
figure()
ik = 7
plot(ws,real(G[ik,ik,:]),'r')
plot(ws,imag(G[ik,ik,:]),'b')

figure()
for ik1 in range(Nk):
    for ik2 in range(Nk):
        plot(ws,real(G[ik1,ik2,:]),'r')
        plot(ws,imag(G[ik1,ik2,:]),'b')

# %%
data = load("../data/Sigma11.npy")
print shape(data)
# Out:
# (31L, 31L, 100L)

# %%
figure()
imshow(real(data[:,:,0]))
colorbar()
figure()
imshow(imag(data[:,:,0]))
colorbar()
